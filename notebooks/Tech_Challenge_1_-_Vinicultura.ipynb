# %% [markdown]
# # Dados de Produção - Avaliação e Montagem - Período 2007 à 2021

# %% [markdown]
# ### Fonte: http://vitibrasil.cnpuv.embrapa.br/index.php?opcao=opt_01 em 11/06/2023
# ### biblioteca de leitura de HTML : pip install html5lib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import probplot

# %% [markdown]
# ### Montagem dos arquivos de Produção - Período 2007 à 2021

# %%
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2007&opcao=opt_02')
producao2007 = leitura[5]
producao2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2007.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2008&opcao=opt_02')
producao2008 = leitura[5]
producao2008.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2008.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2009&opcao=opt_02')
producao2009 = leitura[5]
producao2009.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2009.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2010&opcao=opt_02')
producao2010 = leitura[5]
producao2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2010.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2011&opcao=opt_02')
producao2011 = leitura[5]
producao2011.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2011.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2012&opcao=opt_02')
producao2012 = leitura[5]
producao2012.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2012.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2013&opcao=opt_02')
producao2013 = leitura[5]
producao2013.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2013.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2014&opcao=opt_02')
producao2014 = leitura[5]
producao2014.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2014.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2015&opcao=opt_02')
producao2015 = leitura[5]
producao2015.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2015.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2016&opcao=opt_02')
producao2016 = leitura[5]
producao2016.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2016.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2017&opcao=opt_02')
producao2017 = leitura[5]
producao2017.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2017.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2018&opcao=opt_02')
producao2018 = leitura[5]
producao2018.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2018.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2019&opcao=opt_02')
producao2019 = leitura[5]
producao2019.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2019.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2020&opcao=opt_02')
producao2020 = leitura[5]
producao2020.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2020.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2021&opcao=opt_02')
producao2021 = leitura[5]
producao2021.to_csv("/BcoDados/FIAP/Tech Challenge 1/Producao/Producao2021.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')

# %% [markdown]
# ### Montagem dos arquivos de Comercialização - Período de 2007 à 2021

# %%
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2007&opcao=opt_04')
comercio2007 = leitura[5]
comercio2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2007.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2008&opcao=opt_04')
comercio2008 = leitura[5]
comercio2008.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2008.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2009&opcao=opt_04')
comercio2009 = leitura[5]
comercio2009.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2009.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2010&opcao=opt_04')
comercio2010 = leitura[5]
comercio2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2010.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2011&opcao=opt_04')
comercio2011 = leitura[5]
comercio2011.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2011.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2012&opcao=opt_04')
comercio2012 = leitura[5]
comercio2012.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2012.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2013&opcao=opt_04')
comercio2013 = leitura[5]
comercio2013.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2013.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2014&opcao=opt_04')
comercio2014 = leitura[5]
comercio2014.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2014.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2015&opcao=opt_04')
comercio2015 = leitura[5]
comercio2015.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2015.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2016&opcao=opt_04')
comercio2016 = leitura[5]
comercio2016.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2016.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2017&opcao=opt_04')
comercio2017 = leitura[5]
comercio2017.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2017.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2018&opcao=opt_04')
comercio2018 = leitura[5]
comercio2018.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2018.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2019&opcao=opt_04')
comercio2019 = leitura[5]
comercio2019.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2019.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2020&opcao=opt_04')
comercio2020 = leitura[5]
comercio2020.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2020.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2021&opcao=opt_04')
comercio2021 = leitura[5]
comercio2021.to_csv("/BcoDados/FIAP/Tech Challenge 1/Comercializado/Comercio2021.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')

# %% [markdown]
# ### Montagem dos arquivos de Exportação - Período 2007 à 2021

# %% [markdown]
# #### Exportação de Vinhos de Mesa

# %%
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2007&opcao=opt_06&subopcao=subopt_01')
ExportVinho2007 = leitura[5]
ExportVinho2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2007.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2008&opcao=opt_06&subopcao=subopt_01')
ExportVinho2008 = leitura[5]
ExportVinho2008.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2008.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2009&opcao=opt_06&subopcao=subopt_01')
ExportVinho2009 = leitura[5]
ExportVinho2009.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2009.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2010&opcao=opt_06&subopcao=subopt_01')
ExportVinho2010 = leitura[5]
ExportVinho2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2010.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2011&opcao=opt_06&subopcao=subopt_01')
ExportVinho2011 = leitura[5]
ExportVinho2011.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2011.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2012&opcao=opt_06&subopcao=subopt_01')
ExportVinho2012 = leitura[5]
ExportVinho2012.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2012.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2013&opcao=opt_06&subopcao=subopt_01')
ExportVinho2013 = leitura[5]
ExportVinho2013.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2013.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2014&opcao=opt_06&subopcao=subopt_01')
ExportVinho2014 = leitura[5]
ExportVinho2014.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2014.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2015&opcao=opt_06&subopcao=subopt_01')
ExportVinho2015 = leitura[5]
ExportVinho2015.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2015.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2016&opcao=opt_06&subopcao=subopt_01')
ExportVinho2016 = leitura[5]
ExportVinho2016.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2016.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2017&opcao=opt_06&subopcao=subopt_01')
ExportVinho2017 = leitura[5]
ExportVinho2017.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2017.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2018&opcao=opt_06&subopcao=subopt_01')
ExportVinho2018 = leitura[5]
ExportVinho2018.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2018.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2019&opcao=opt_06&subopcao=subopt_01')
ExportVinho2019 = leitura[5]
ExportVinho2019.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2019.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2020&opcao=opt_06&subopcao=subopt_01')
ExportVinho2020 = leitura[5]
ExportVinho2020.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2020.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2021&opcao=opt_06&subopcao=subopt_01')
ExportVinho2021 = leitura[5]
ExportVinho2021.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportVinho2021.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')

# %% [markdown]
# #### Exportação de Espumantes

# %%
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2007&opcao=opt_06&subopcao=subopt_02')
ExportEspum2007 = leitura[5]
ExportEspum2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2007.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2008&opcao=opt_06&subopcao=subopt_02')
ExportEspum2008 = leitura[5]
ExportEspum2008.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2008.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2009&opcao=opt_06&subopcao=subopt_02')
ExportEspum2009 = leitura[5]
ExportEspum2009.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2009.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2010&opcao=opt_06&subopcao=subopt_02')
ExportEspum2010 = leitura[5]
ExportEspum2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2010.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2011&opcao=opt_06&subopcao=subopt_02')
ExportEspum2011 = leitura[5]
ExportEspum2011.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2011.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2012&opcao=opt_06&subopcao=subopt_02')
ExportEspum2012 = leitura[5]
ExportEspum2012.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2012.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2013&opcao=opt_06&subopcao=subopt_02')
ExportEspum2013 = leitura[5]
ExportEspum2013.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2013.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2014&opcao=opt_06&subopcao=subopt_02')
ExportEspum2014 = leitura[5]
ExportEspum2014.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2014.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2015&opcao=opt_06&subopcao=subopt_02')
ExportEspum2015 = leitura[5]
ExportEspum2015.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2015.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2016&opcao=opt_06&subopcao=subopt_02')
ExportEspum2016 = leitura[5]
ExportEspum2016.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2016.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2017&opcao=opt_06&subopcao=subopt_02')
ExportEspum2017 = leitura[5]
ExportEspum2017.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2017.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2018&opcao=opt_06&subopcao=subopt_02')
ExportEspum2018 = leitura[5]
ExportEspum2018.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2018.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2019&opcao=opt_06&subopcao=subopt_02')
ExportEspum2019 = leitura[5]
ExportEspum2019.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2019.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2020&opcao=opt_06&subopcao=subopt_02')
ExportEspum2020 = leitura[5]
ExportEspum2020.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2020.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2021&opcao=opt_06&subopcao=subopt_02')
ExportEspum2021 = leitura[5]
ExportEspum2021.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportEspum2021.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')

# %% [markdown]
# #### Exportação de Uvas Frescas

# %%
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2007&opcao=opt_06&subopcao=subopt_03')
ExportUvas2007 = leitura[5]
ExportUvas2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2007.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2008&opcao=opt_06&subopcao=subopt_03')
ExportUvas2008 = leitura[5]
ExportUvas2008.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2008.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2009&opcao=opt_06&subopcao=subopt_03')
ExportUvas2009 = leitura[5]
ExportUvas2009.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2009.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2010&opcao=opt_06&subopcao=subopt_03')
ExportUvas2010 = leitura[5]
ExportUvas2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2010.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2011&opcao=opt_06&subopcao=subopt_03')
ExportUvas2011 = leitura[5]
ExportUvas2011.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2011.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2012&opcao=opt_06&subopcao=subopt_03')
ExportUvas2012 = leitura[5]
ExportUvas2012.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2012.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2013&opcao=opt_06&subopcao=subopt_03')
ExportUvas2013 = leitura[5]
ExportUvas2013.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2013.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2014&opcao=opt_06&subopcao=subopt_03')
ExportUvas2014 = leitura[5]
ExportUvas2014.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2014.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2015&opcao=opt_06&subopcao=subopt_03')
ExportUvas2015 = leitura[5]
ExportUvas2015.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2015.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2016&opcao=opt_06&subopcao=subopt_03')
ExportUvas2016 = leitura[5]
ExportUvas2016.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2016.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2017&opcao=opt_06&subopcao=subopt_03')
ExportUvas2017 = leitura[5]
ExportUvas2017.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2017.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2018&opcao=opt_06&subopcao=subopt_03')
ExportUvas2018 = leitura[5]
ExportUvas2018.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2018.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2019&opcao=opt_06&subopcao=subopt_03')
ExportUvas2019 = leitura[5]
ExportUvas2019.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2019.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2020&opcao=opt_06&subopcao=subopt_03')
ExportUvas2020 = leitura[5]
ExportUvas2020.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2020.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2021&opcao=opt_06&subopcao=subopt_03')
ExportUvas2021 = leitura[5]
ExportUvas2021.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportUvas2021.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')

# %% [markdown]
# #### Exportação de Uvas Frescas

# %%
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2007&opcao=opt_06&subopcao=subopt_04')
ExportSucos2007 = leitura[5]
ExportSucos2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2007.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',  
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2008&opcao=opt_06&subopcao=subopt_04')
ExportSucos2008 = leitura[5]
ExportSucos2008.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2008.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',  
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2009&opcao=opt_06&subopcao=subopt_04')
ExportSucos2009 = leitura[5]
ExportSucos2009.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2009.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',  
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2010&opcao=opt_06&subopcao=subopt_04')
ExportSucos2010 = leitura[5]
ExportSucos2007.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2010.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2011&opcao=opt_06&subopcao=subopt_04')
ExportSucos2011 = leitura[5]
ExportSucos2011.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2011.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',  
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2012&opcao=opt_06&subopcao=subopt_04')
ExportSucos2012 = leitura[5]
ExportSucos2012.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2012.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2013&opcao=opt_06&subopcao=subopt_04')
ExportSucos2013 = leitura[5]
ExportSucos2013.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2013.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',  
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2014&opcao=opt_06&subopcao=subopt_04')
ExportSucos2014 = leitura[5]
ExportSucos2014.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2014.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',  
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2015&opcao=opt_06&subopcao=subopt_04')
ExportSucos2015 = leitura[5]
ExportSucos2015.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2015.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2016&opcao=opt_06&subopcao=subopt_04')
ExportSucos2016 = leitura[5]
ExportSucos2016.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2016.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False,  
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2017&opcao=opt_06&subopcao=subopt_04')
ExportSucos2017 = leitura[5]
ExportSucos2017.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2017.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',  
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2018&opcao=opt_06&subopcao=subopt_04')
ExportSucos2018 = leitura[5]
ExportSucos2018.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2018.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',
                    index =False,  
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2019&opcao=opt_06&subopcao=subopt_04')
ExportSucos2019 = leitura[5]
ExportSucos2019.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2019.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2020&opcao=opt_06&subopcao=subopt_04')
ExportSucos2020 = leitura[5]
ExportSucos2020.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2020.csv", 
                    encoding='ISO-8859-1', 
                    sep=';', 
                    index =False, 
                    decimal=',')
leitura = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2021&opcao=opt_06&subopcao=subopt_04')
ExportSucos2021 = leitura[5]
ExportSucos2021.to_csv("/BcoDados/FIAP/Tech Challenge 1/Exportacao/ExportSucos2021.csv", 
                    encoding='ISO-8859-1', 
                    sep=';',  
                    index =False, 
                    decimal=',')

# %%
dados = pd.read_csv('/BcoDados/FIAP//Tech Challenge 1/Producao/Producao2012.csv',
	                encoding='UTF_8',
	                sep=';',
	                thousands='.',
	                decimal=',')
pd.options.display.float_format = '{:.2f}'.format

# %%
dados
# Out:
#                                      Produto Quantidade (L.)
# 0                              VINHO DE MESA     212.777.037
# 1                                      Tinto     175.875.432
# 2                                     Branco      34.938.249
# 3                                     Rosado       1.963.356
# 4              VINHO FINO DE MESA (VINÍFERA)      45.200.730
# 5                                      Tinto      24.027.589
# 6                                     Branco      20.647.238
# 7                                     Rosado         525.903
# 8                                       SUCO      70.066.732
# 9                       Suco de uva integral      31.908.829
# 10                   Suco de uva concentrado      37.624.855
# 11                       Suco de uva adoçado         533.048
# 12                      Suco de uva orgânico               -
# 13                 Suco de uva reconstituído               -
# ...
