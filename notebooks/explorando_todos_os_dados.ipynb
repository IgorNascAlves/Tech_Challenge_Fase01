# %%
import pandas as pd

# %%
df_Comercio = pd.read_csv('../data/dados_tratados/Comercio.csv', sep=';')
df_Comercio.head()
# Out:
#                   Tipo              Produto      1970       1971       1972  \
# 0        VINHO DE MESA        VINHO DE MESA  98327606  114399031  118377367
# 1             vm_Tinto                Tinto  83300735   98522869  101167932
# 2            vm_Rosado               Rosado    107681     542274    7770851
# 3            vm_Branco               Branco  14919190   15333888    9438584
# 4  VINHO  FINO DE MESA  VINHO  FINO DE MESA   4430629    4840369    5602091
#
#         1973      1974       1975       1976       1977  ...       2012  \
# 0  116617910  94173324  108031792  139238614  140813114  ...  206969571
# 1   98196747  77167303   91528090  116407222  116609545  ...  173964776
# 2    8425617   8891367    7261777   11748047   15195525  ...    1738134
# 3    9995546   8114654    9241925   11083345    9008044  ...   31266661
# 4    7202830   7571802    8848303   14095648   14975330  ...   22469950
#
#         2013       2014       2015       2016       2017       2018  \
# ...

# %%
df_Completo = pd.read_csv('../data/dados_tratados/df_Completo.csv', sep=',')
df_Completo.head()
# Out:
#    Id                 País  1970_Quantidade (Kg)  1970_Valor (US$)  \
# 0   1             Alemanha                     0               0.0
# 1   2               Angola                     0               0.0
# 2   3    Antigua e Barbuda                     0               0.0
# 3   4  Antilhas Holandesas                     0               0.0
# 4   5            Argentina                     0               0.0
#
#    1971_Quantidade (Kg)  1971_Valor (US$)  1972_Quantidade (Kg)  \
# 0                     0                 0                     0
# 1                     0                 0                     0
# 2                     0                 0                     0
# 3                     0                 0                     0
# 4                     0                 0                     0
#
#    1972_Valor (US$)  1973_Quantidade (Kg)  1973_Valor (US$)  ...  \
# 0                 0                     0                 0  ...
# ...
